# %%
is_student=True
has_id=True
in_dress=True

# %%
if is_student and has_id and in_dress:
    print("Entry allowed. Can enter the classroom")

elif is_student and (has_id or in_dress):
    print("Partial entry allowed!")

else:
    print("Not allowed in classroom.")
# Out:
# Entry allowed. Can enter the classroom

# %%
a = ["Example", "one", 3]

if "Example" in a:
    print("Found Example")
# Out:
# Found Example

# %%
a = [1, 2, 3]
b = a          
c = [1, 2, 3]  

print(a is b)      
print(a is not b)  

print(a is c)      
print(a is not c)
# Out:
# True
# False
# False
# True
